# %% [markdown]
# ACTIVIDAD #3: USO DE SOFTWARE PARA BÚSQUEDA
#
# MAURICIO ARMANDO VILLATORO ALVARADO
#
# 2128154
#
# IMTC
#
# N1

# %%
#Cargar librerías
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)


#Cargar datos.
keras.datasets.mnist.load_data(path="mnist.npz")
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


#Prerpocesamiento de datos.
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# 2.15.0

# %%
#Selección y entrenamiento del modelo.
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2402 - accuracy: 0.9280
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1023 - accuracy: 0.9690
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0709 - accuracy: 0.9778
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0523 - accuracy: 0.9833
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0407 - accuracy: 0.9866
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0351 - accuracy: 0.9887
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0287 - accuracy: 0.9906
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0244 - accuracy: 0.9915
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0191 - accuracy: 0.9934
# Epoch 10/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0209 - accuracy: 0.9929

# %%
# 5. Prueba de modelo
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print("Exactitud de predicción del modelo:", test_accuracy)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.1063 - accuracy: 0.9772
# Exactitud de predicción del modelo: 0.9771999716758728

# %%
for i in range(5):
    # Selecciona una imagen aleatoria de los datos de prueba
    index = np.random.randint(0, len(test_images))
    image = test_images[index]
    label = test_labels[index]

    # Realiza la predicción
    prediction = model.predict(np.array([image]))
    predicted_label = np.argmax(prediction)

    # Muestra la imagen
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.show()

    print("Predicción:", predicted_label)
    print("Valor real:", label)
# Out:
# 1/1 [==============================] - 0s 209ms/step
# Predicción: 3
# Valor real: 3
# 1/1 [==============================] - 0s 23ms/step
# Predicción: 7
# Valor real: 7
# 1/1 [==============================] - 0s 28ms/step
# Predicción: 2
# Valor real: 2
# 1/1 [==============================] - 0s 33ms/step
# Predicción: 2
# Valor real: 2
# 1/1 [==============================] - 0s 28ms/step
# Predicción: 6
# Valor real: 6
